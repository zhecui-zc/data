# %%
import pandas as pd
import numpy

# %%
data = pd.read_csv("./test_point_15.csv")

# %%
data['Test_point'] = '15'

# %%
data.to_csv('./test_point_15.csv')

# %%
import pandas as pd
 
df1 = pd.read_csv("./test_point_1.csv")#读取第一个文件
 
df2 = pd.read_csv("./test_point_2.csv")#读取第二个文件
 
df3 = pd.read_csv("./test_point_3.csv")#读取第三个文件
df4 = pd.read_csv("./test_point_4.csv") 
df5 = pd.read_csv("./test_point_5.csv")    
df6 = pd.read_csv("./test_point_6.csv")    
df7 = pd.read_csv("./test_point_7.csv")        
df8 = pd.read_csv("./test_point_8.csv")    
df10 = pd.read_csv("./test_point_10.csv")    
df11 = pd.read_csv("./test_point_11.csv")   
df12 = pd.read_csv("./test_point_12.csv")    
df13 = pd.read_csv("./test_point_13.csv")    
df14 = pd.read_csv("./test_point_14.csv") 
df15 = pd.read_csv("./test_point_15.csv")    


file = [df1, df2, df3, df4, df5, df6, df7, df8, df10, df11, df12, df13, df14, df15]
 

outfile = pd.concat(file)#竖着拼
 
outfile.to_csv("All.csv",index=0, sep=',')
 
print(outfile.shape)#查看文件大小
# Out:
# (14120, 12)

# %%
df = pd.read_csv("./All.csv")

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0         macAddress  locationCoordinate_x  \
# 0                 0           0  f4:02:28:5a:28:63              17.73704
# 1                 1           1  f4:02:28:5a:28:63              17.73704
# 2                 2           2  f4:02:28:5a:28:63              17.73704
# 3                 3           3  f4:02:28:5a:28:63              17.73704
# 4                 4           4  f4:02:28:5a:28:63              17.73704
# ...             ...         ...                ...                   ...
# 14115          1083        1083  dc:a6:32:26:67:ab              66.00000
# 14116          1084        1084  dc:a6:32:26:67:ab              66.00000
# 14117          1085        1085  dc:a6:32:26:67:ab              66.00000
# 14118          1086        1086  dc:a6:32:26:67:ab              66.00000
# 14119          1087        1087  dc:a6:32:26:67:ab              66.00000
#
#        locationCoordinate_y  confidenceFactor  maxDetectedRssi  \
# 0                 34.657078                40              -59
# 1                 34.657078                40              -59
# 2                 34.657078                40              -59
# 3                 34.657078                40              -59
# 4                 34.657078                40              -59
# ...                     ...               ...              ...
# 14115             28.000002                80              -51
# 14116             28.000002                80              -51
# 14117             28.000002                80              -49
# 14118             28.000002                80              -49
# 14119             28.000002                80              -49
#
#                        CMX_lastSeen            Real_Time       RMSE  \
# 0      2022-07-08T12:18:37.455+0100  2022-07-08 12:22:58  34.962825
# 1      2022-07-08T12:18:37.455+0100  2022-07-08 12:23:00  34.962825
# 2      2022-07-08T12:18:37.455+0100  2022-07-08 12:23:01  34.962825
# 3      2022-07-08T12:18:37.455+0100  2022-07-08 12:23:02  34.962825
# 4      2022-07-08T12:18:37.455+0100  2022-07-08 12:23:03  34.962825
# ...                             ...                  ...        ...
# 14115  2022-07-11T16:35:28.438+0100  2022-07-11 16:35:28   1.794670
# 14116  2022-07-11T16:35:28.438+0100  2022-07-11 16:35:29   1.794670
# 14117  2022-07-11T16:35:30.478+0100  2022-07-11 16:35:30   1.794670
# 14118  2022-07-11T16:35:30.478+0100  2022-07-11 16:35:31   1.794670
# 14119  2022-07-11T16:35:32.479+0100  2022-07-11 16:35:32   1.794670
#
#        Test_point  Unnamed: 0.2
# 0               1           NaN
# 1               1           NaN
# 2               1           NaN
# 3               1           NaN
# 4               1           NaN
# ...           ...           ...
# 14115          15        1083.0
# 14116          15        1084.0
# 14117          15        1085.0
# 14118          15        1086.0
# 14119          15        1087.0
#
# [14120 rows x 12 columns]
